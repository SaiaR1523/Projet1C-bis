# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
df = pd.read_csv('data2010-2011s1.csv', encoding = "ISO-8859-1")  #on a 8 colonnes
df.head  #permet de voir les première lignes du data set
# Out:
# <bound method NDFrame.head of        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 245898    558637     22032         BOTANICAL LILY GREETING CARD        12
# 245899    558637     22028         PENNY FARTHING BIRTHDAY CARD        12
# 245900    558637     22033         BOTANICAL ROSE GREETING CARD        12
# 245901    558637     22029               SPACEBOY BIRTHDAY CARD        12
# 245902    558637     22024           RAINY LADIES BIRTHDAY CARD        12
#
# ...

# %%
dfproduit = df[['StockCode','Description' , 'UnitPrice' ]].copy()  #pour suppriemr les doublons entre les 3 colonnes de num produit
#description et prix unitaire
dfproduit.drop_duplicates(subset=['StockCode'],inplace=True)
dfproduit
# Out:
#        StockCode                          Description  UnitPrice
# 0         85123A   WHITE HANGING HEART T-LIGHT HOLDER       2.55
# 1          71053                  WHITE METAL LANTERN       3.39
# 2         84406B       CREAM CUPID HEARTS COAT HANGER       2.75
# 3         84029G  KNITTED UNION FLAG HOT WATER BOTTLE       3.39
# 4         84029E       RED WOOLLY HOTTIE WHITE HEART.       3.39
# ...          ...                                  ...        ...
# 240428     23317                BLUE REFECTORY CLOCK        9.95
# 240433     23017             APOTHECARY MEASURING JAR      12.50
# 240440     23018      LARGE APOTHECARY MEASURING JAR       12.50
# 240768     23025       DRAWER KNOB VINTAGE GLASS BALL       2.08
# 242905    79161A                                  NaN       0.00
#
# [3651 rows x 3 columns]

# %%
for index, row in dfproduit.iterrows():
    
    # Print the index and row data
    print(index, row ['StockCode'],  row['Description'], row ['UnitPrice'])
# Out:
# 0 85123A WHITE HANGING HEART T-LIGHT HOLDER 2.55
# 1 71053 WHITE METAL LANTERN 3.39
# 2 84406B CREAM CUPID HEARTS COAT HANGER 2.75
# 3 84029G KNITTED UNION FLAG HOT WATER BOTTLE 3.39
# 4 84029E RED WOOLLY HOTTIE WHITE HEART. 3.39
# 5 22752 SET 7 BABUSHKA NESTING BOXES 7.65
# 6 21730 GLASS STAR FROSTED T-LIGHT HOLDER 4.25
# 7 22633 HAND WARMER UNION JACK 1.85
# 8 22632 HAND WARMER RED POLKA DOT 1.85
# 9 84879 ASSORTED COLOUR BIRD ORNAMENT 1.69
# 10 22745 POPPY'S PLAYHOUSE BEDROOM  2.1
# 11 22748 POPPY'S PLAYHOUSE KITCHEN 2.1
# 12 22749 FELTCRAFT PRINCESS CHARLOTTE DOLL 3.75
# 13 22310 IVORY KNITTED MUG COSY  1.65
# 14 84969 BOX OF 6 ASSORTED COLOUR TEASPOONS 4.25
# 15 22623 BOX OF VINTAGE JIGSAW BLOCKS  4.95
# 16 22622 BOX OF VINTAGE ALPHABET BLOCKS 9.95
# 17 21754 HOME BUILDING BLOCK WORD 5.95
# 18 21755 LOVE BUILDING BLOCK WORD 5.95
# 19 21777 RECIPE BOX WITH METAL HEART 7.95
# 20 48187 DOORMAT NEW ENGLAND 7.95
# 21 22960 JAM MAKING SET WITH JARS 4.25
# ...

# %%
dffacture =  df [['InvoiceNo' , 'InvoiceDate' , 'Country']].copy()  #pour suppriemr les doublons entre les 3 colonnes de num produit
        #description et prix unitaire
dffacture.drop_duplicates(subset=['InvoiceNo'],inplace=True)
dffacture
# Out:
#        InvoiceNo      InvoiceDate         Country
# 0         536365   12/1/2010 8:26  United Kingdom
# 7         536366   12/1/2010 8:28  United Kingdom
# 9         536367   12/1/2010 8:34  United Kingdom
# 21        536368   12/1/2010 8:34  United Kingdom
# 25        536369   12/1/2010 8:35  United Kingdom
# ...          ...              ...             ...
# 245808    558633  6/30/2011 19:13  United Kingdom
# 245822    558634  6/30/2011 19:27  United Kingdom
# 245838    558635  6/30/2011 19:52  United Kingdom
# 245852    558636  6/30/2011 19:58  United Kingdom
# 245869    558637  6/30/2011 20:08  United Kingdom
#
# [12795 rows x 3 columns]

# %%
date= dffacture[['InvoiceDate']]
df2 = pd.to_datetime(date).date()
print(df2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [40], in <cell line: 2>()
#       1 date= dffacture[['InvoiceDate']]
# ----> 2 df2 = pd.to_datetime(date).date()
#       3 print(df2)
#
# File ~\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1054, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1052         result = arg._constructor(values, index=arg.index, name=arg.name)
#    1053 elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
# -> 1054     result = _assemble_from_unit_mappings(arg, errors, tz)
#    1055 elif isinstance(arg, Index):
#    1056     cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#
# File ~\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1160, in _assemble_from_unit_mappings(arg, errors, tz)
#    1158 if len(req):
# ...
